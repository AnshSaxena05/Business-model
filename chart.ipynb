# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("result.csv")

# %%
df
# Out:
#                                               Category  \
# 0    Computers&Accessories|Accessories&Peripherals|...
# 1    Computers&Accessories|NetworkingDevices|Networ...
# 2    Electronics|HomeTheater,TV&Video|Accessories|C...
# 3    Electronics|HomeTheater,TV&Video|Televisions|S...
# 4    Electronics|HomeTheater,TV&Video|Accessories|R...
# ..                                                 ...
# 206  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
# 207  Home&Kitchen|Heating,Cooling&AirQuality|Parts&...
# 208  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
# 209  Home&Kitchen|Heating,Cooling&AirQuality|Fans|P...
# 210  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...
#
#      Company Loss after prediction  Min Discount for Max Rating  Max Rating  \
# 0                        3384.3380                       0.3620         4.5
# 1                        4145.6592                       0.3873         4.5
# 2                        1267.9170                       0.3490         4.4
# 3                       22793.5020                       0.1074         4.3
# 4                        8876.6775                       0.5045         4.5
# ..                             ...                          ...         ...
# 206                       330.0000                       0.3300         4.4
# 207                       584.6900                       0.5900         4.1
# 208                      2638.0800                       0.4800         4.3
# 209                       526.8640                       0.4000         4.1
# 210                       121.0300                       0.4900         4.3
#
#      Original Company Loss  Company Revenue Gain
# 0                 5613.170             2228.8320
# 1                 5163.680             1018.0208
# 2                 2304.220             1036.3030
# 3                75242.800            52449.2980
# 4                12140.740             3264.0625
# ..                     ...                   ...
# 206                330.000                0.0000
# 207                584.690                0.0000
# 208               2638.080                0.0000
# 209                526.864                0.0000
# 210                121.030                0.0000
#
# [211 rows x 6 columns]

# %%
selected_category = 'Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables'
x = df[df['Category'] == selected_category]

a = x['Original Company Loss'].values[0]
b = x['Company Loss after prediction'].values[0]
c = x['Company Revenue Gain'].values[0]

plt.bar(x=['Before', 'After', 'Gain'], height=[a,b,c])
plt.show()
